# %% [markdown]
# # Word Clouds
#
# A word cloud is an easy and convenient way to summarize and visualize written data.
#
# One of the reasons this is so easy and convenient is that someone wrote a module to do most of the hard work.  This is a good opportunity for me to show you this `try-except` trick.  If the `wordcloud` module is not installed, when you try to import it, you'll get an error.  However, since it's put inside a `try`, when it fails then the module is installed using `!pip install`.
#
# The first time you run this next cell, it will probably take a long time and you might see some messages about the module being downloaded and installed.  The second time you run it, it will run faster and no messages will follow it.

# %%
try:
    from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
except:
    ! pip install wordcloud
    from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
    
import numpy as np
import pandas as pd
#from os import path
#from PIL import Image

# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

import warnings
warnings.filterwarnings("ignore")

# %%
bf = pd.read_csv("bigfoot_descriptions.csv", index_col = 0)

bf
# Out:
#                                                observed
# 0     I was canoeing on the Sipsey river in Alabama....
# 1     Ed L. was salmon fishing with a companion in P...
# 2     While attending U.R.I in the Fall of 1974,I wo...
# 3     Hello, My name is Doug and though I am very re...
# 4     It was May 1984. Two friends and I were up in ...
# ...                                                 ...
# 5016  while camping protecting other equipment befor...
# 5017  I was on my way to work on a Saturday morning ...
# 5018  On the twenty sixth and again on the twenty se...
# 5019  I was hunting on me and my neighbor's property...
# 5020  I was riding with a friend in the summer of 19...
#
# [4983 rows x 1 columns]

# %%
# Start with one review:
text = bf.observed[0]

# Create and generate a word cloud image:
wordcloud = WordCloud(background_color="white").generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
text = " ".join(i for i in bf.observed)

# %%
wordcloud = WordCloud(background_color="white").generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
ufo = pd.read_csv("SightingDescription.csv", encoding = "Latin1")

ufo.Summary
# Out:
# 0                                                    Circle
# 1                                                 Fireball.
# 2           Triangle.  (( Note:  Witness provides no oth...
# 3          ((HOAX??))  4th  of July ufo and a image of a...
# 4          ((HOAX??))  This was a red light which was mo...
#                                 ...
# 144213              Zippy light above Red Rocks Ampitheater
# 144214                                                 zoom
# 144215    Zoom, zoom back and forth in the sky very quic...
# 144216    zoomed camera on light and filmed did not look...
# 144217    Zoomes left to right then still as the red fla...
# Name: Summary, Length: 144218, dtype: object

# %%
ufo_text = " ".join(i for i in ufo.Summary)

wordcloud = WordCloud(background_color="white").generate(ufo_text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
from urllib.request import urlopen 
import re
def read_url(url): 
    return re.sub('\\s+', ' ', urlopen(url).read().decode())

huck_finn_url = 'https://www.inferentialthinking.com/data/huck_finn.txt'
huck_finn_text = read_url(huck_finn_url)

little_women_url = 'https://www.inferentialthinking.com/data/little_women.txt'
little_women_text = read_url(little_women_url)

# %%
wordcloud = WordCloud(background_color="white", colormap="rainbow").generate(little_women_text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
DeclarationofIndependence = read_url('https://cdn.serc.carleton.edu/files/teaching_computation/workshop_2018/activities/plain_text_version_declaration_inde.txt')

wordcloud = WordCloud(background_color="white", colormap ="flag").generate(DeclarationofIndependence)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
wordcloud = WordCloud(background_color="white", colormap ="flag_r").generate(DeclarationofIndependence)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
wordcloud = WordCloud(background_color="white").generate(huck_finn_text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
